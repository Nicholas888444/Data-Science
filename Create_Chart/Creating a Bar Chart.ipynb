# %% [markdown]
# # Creating a Bar Chart
# A **bar chart**, also known as a bar graph, is a common type of data visualization used to represent categorical data. It displays data using rectangular bars, where the length or height of each bar is proportional to the quantity or value it represents. Bar charts are particularly effective for comparing the values of different categories or groups.
#
# In this tutorial, we will create a bar chart to visualize and compare the GDP of the top 10 countries in 2020.

# %% [markdown]
# ### Step 1: Import the Required Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2: Load and Explore the Dataset

# %%
df = pd.read_csv('https://raw.githubusercontent.com/yangliuiuk/data/main/gdp.csv')
df.head()
# Out:
#                   Country Name Code          1960          1961          1962  \
# 0                        Aruba  ABW           NaN           NaN           NaN
# 1  Africa Eastern and Southern  AFE  1.931311e+10  1.972349e+10  2.149392e+10
# 2                  Afghanistan  AFG  5.377778e+08  5.488889e+08  5.466667e+08
# 3   Africa Western and Central  AFW  1.040428e+10  1.112805e+10  1.194335e+10
# 4                       Angola  AGO           NaN           NaN           NaN
#
#            1963          1964          1965          1966          1967  ...  \
# 0           NaN           NaN           NaN           NaN           NaN  ...
# 1  2.573321e+10  2.352744e+10  2.681057e+10  2.915216e+10  3.017317e+10  ...
# 2  7.511112e+08  8.000000e+08  1.006667e+09  1.400000e+09  1.673333e+09  ...
# 3  1.267652e+10  1.383858e+10  1.486247e+10  1.583285e+10  1.442643e+10  ...
# 4           NaN           NaN           NaN           NaN           NaN  ...
#
# ...

# %% [markdown]
# ### Step 3: Extract Data for the Year 2020
# Extract the GDP data for the year 2020 and sort the DataFrame in descending order based on GDP values.

# %%
# Extract GDP data for the year 2020 and sort by GDP in descending order
df_2020 = df[['Country Name', '2020']].sort_values(by='2020', ascending=False)
df_2020[0:50]
#df_2020.iloc[0:50, :]
# Out:
#                                           Country Name          2020
# 259                                              World  8.474698e+13
# 95                                         High income  5.346108e+13
# 181                                       OECD members  5.239268e+13
# 198                          Post-demographic dividend  4.959447e+13
# 103                                   IDA & IBRD total  3.213931e+13
# 140                                Low & middle income  3.099315e+13
# 156                                      Middle income  3.053534e+13
# 102                                          IBRD only  2.990058e+13
# 63                                 East Asia & Pacific  2.709740e+13
# 249                                Upper middle income  2.315067e+13
# 170                                      North America  2.260530e+13
# 142                          Late-demographic dividend  2.243339e+13
# 65                               Europe & Central Asia  2.212158e+13
# ...

# %% [markdown]
# Here note that the dataset includes regions as country names. So, we need to examine the first number of rows in order to select actual countries.
#
# The top 10 countries with highest GDP are:
#
# - United States
# - China
# - Japan
# - Germany
# - United Kingdom
# - India
# - France
# - Italy
# - Canada
# - Korea, Rep.

# %% [markdown]
# ### Step 4: Select the Top 10 GDP Countries

# %%
# List of the 10 countries you want to compare
countries_to_compare = [
    'United States',
    'China',
    'Japan',
    'Germany',
    'United Kingdom',
    'India',
    'France',
    'Italy',
    'Canada',
    'Korea, Rep.'
]

# Filter the DataFrame to include only the selected countries
selected_countries_df = df[df['Country Name'].isin(countries_to_compare)] #Selects the rows of the countries
#df[logical expression] selects rows with true values. Logical expression gives array of true false
selected_countries_df = selected_countries_df[['Country Name', '2020']].sort_values(by='2020', ascending=False)
selected_countries_df
# Out:
#        Country Name          2020
# 251   United States  2.095303e+13
# 40            China  1.472273e+13
# 119           Japan  5.057759e+12
# 55          Germany  3.846414e+12
# 81   United Kingdom  2.759804e+12
# 109           India  2.660245e+12
# 77           France  2.630318e+12
# 116           Italy  1.888709e+12
# 35           Canada  1.645423e+12
# 126     Korea, Rep.  1.637896e+12

# %% [markdown]
# ### Step 5: Create the Bar Chart

# %%
# Set the figure size
plt.figure(figsize=(12, 6))

# Convert GDP values to billions
selected_countries_df['GDP (Billions)'] = selected_countries_df['2020'] / 1e9  # Divide by 1 billion
selected_countries_df
# Out:
#        Country Name          2020  GDP (Billions)
# 251   United States  2.095303e+13    20953.030000
# 40            China  1.472273e+13    14722.730698
# 119           Japan  5.057759e+12     5057.758959
# 55          Germany  3.846414e+12     3846.413929
# 81   United Kingdom  2.759804e+12     2759.804062
# 109           India  2.660245e+12     2660.245249
# 77           France  2.630318e+12     2630.317731
# 116           Italy  1.888709e+12     1888.709444
# 35           Canada  1.645423e+12     1645.423408
# 126     Korea, Rep.  1.637896e+12     1637.895803

# %%
# Create the bar chart
plt.bar(selected_countries_df['Country Name'], selected_countries_df['GDP (Billions)'], color='blue', alpha=0.7)
plt.xlabel('Country')
plt.ylabel('GDP (Billions)')
plt.title('GDP Comparison of Selected Countries in 2020')
plt.xticks(rotation=45)  # Rotate the x-axis labels for better readability

# Show the bar chart
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step 6: Data analysis and interpretation

# %% [markdown]
# The United States had the highest GDP among the selected countries in 2020, making it the world's largest economy by a significant margin. It represents a robust and well-developed economy.
#
# China is the second-largest economy globally and has experienced rapid economic growth over the years, making it a major player in the global economy.
#
# Japan has a sizable economy and is known for its advanced technology, manufacturing, and export-oriented industries.
#
# Overall, this data reflects the economic power and diversity of these top 10 countries. The United States and China have the largest economies, followed by several major European and Asian economies, each with its own unique economic strengths and characteristics.
